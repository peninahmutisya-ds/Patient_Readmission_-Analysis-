# %%
#!pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 4665c10899bc413b639194f6fb8665a5c70f7db5
# python                : 3.13.5
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : Intel64 Family 6 Model 94 Stepping 3, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_United States.1252
#
# pandas                : 2.3.2
# numpy                 : 2.3.3
# pytz                  : 2025.2
# dateutil              : 2.9.0.post0
# pip                   : 25.1
# Cython                : None
# sphinx                : None
# IPython               : 9.1.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : 4.13.4
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# ...

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
help(pd.qcut)
# Out:
# Help on function qcut in module pandas.core.reshape.tile:
#
# qcut(
#     x,
#     q,
#     labels=None,
#     retbins: 'bool' = False,
#     precision: 'int' = 3,
#     duplicates: 'str' = 'raise'
# )
#     Quantile-based discretization function.
#
#     Discretize variable into equal-sized buckets based on rank or based
#     on sample quantiles. For example 1000 values for 10 quantiles would
#     produce a Categorical object indicating quantile membership for each data point.
#
#     Parameters
#     ----------
#     x : 1d ndarray or Series
#     q : int or list-like of float
#         Number of quantiles. 10 for deciles, 4 for quartiles, etc. Alternately
#         array of quantiles, e.g. [0, .25, .5, .75, 1.] for quartiles.
#     labels : array or False, default None
#         Used as labels for the resulting bins. Must be of the same length as
#         the resulting bins. If False, return only integer indicators of the
#         bins. If True, raises an error.
# ...

# %%
pd.qcut??
# Out:
# Signature:
# pd.qcut(
#     x,
#     q,
#     labels=None,
#     retbins: 'bool' = False,
#     precision: 'int' = 3,
#     duplicates: 'str' = 'raise',
# )
# Source:
# def qcut(
#     x,
#     q,
#     labels=None,
#     retbins: bool = False,
#     precision: int = 3,
#     duplicates: str = "raise",
# ):
#     """
#     Quantile-based discretization function.
#
#     Discretize variable into equal-sized buckets based on rank or based
#     on sample quantiles. For example 1000 values for 10 quantiles would
#     produce a Categorical object indicating quantile membership for each data point.
#
#     Parameters
#     ----------
#     x : 1d ndarray or Series
#     q : int or list-like of float
#         Number of quantiles. 10 for deciles, 4 for quartiles, etc. Alternately
#         array of quantiles, e.g. [0, .25, .5, .75, 1.] for quartiles.
#     labels : array or False, default None
#         Used as labels for the resulting bins. Must be of the same length as
# ...

# %% [markdown]
# # Patient Readmission Analysis
#
# 1. Problem statement:
#    - Hospital wants to know why patients are readmitted after discharge OR
#    - Why are patient readmitted OR
#    - Understand why the rate of readmission is increasing
# 2. Clean the data
# 3. Transform the data where necessary
# 4. Analy the data (what drives readmission)
#    - Get insights
# 5. Make Recommendations

# %%
#storing the dataset inside a Dataframe
df = pd.read_csv('patient_readmission.csv')

# %%
df.shape
# Out:
# (74, 13)

# %%
df.head()
# Out:
#    patient_id          name    gender  age     city   department     doctor  \
# 0        3001  Patient_3001      Male   54   Lagos   Orthopedics   Dr. Musa
# 1        3002  Patient_3002   female    81    Abuja   Pediatrics   Dr. Musa
# 2        3003  Patient_3003      Male   47    Enugu    Neurology  Dr. Smith
# 3        3004  Patient_3004      MALE   87   Lagos      Oncology  Dr. Okeke
# 4        3005  Patient_3005   female    79    Lagos    Neurology  Dr. Smith
#
#   admission_date discharge_date bill_amount insurance diagnosis readmitted
# 0     2024-06-28     2024-07-11      391724       Yes    Cancer        Yes
# 1     2024-06-10     2024-06-18      265621       Yes  Diabetes        Yes
# 2     2024-06-16     2024-06-24     487,807       NaN  Fracture        Yes
# 3     2024-06-05            NaN      391458       NaN  Diabetes        Yes
# 4     2024-06-27     2024-06-30         NaN      yes     Cancer         No

# %%
df.tail()
# Out:
#     patient_id          name    gender  age     city   department     doctor  \
# 69        3070  Patient_3070      Male   25    Enugu     Oncology  Dr. Adams
# 70        3009  Patient_3009   female    74   Lagos      Oncology  Dr. Okeke
# 71        3038  Patient_3038   female    59     Kano   Pediatrics  Dr. Adams
# 72        3041  Patient_3041    Female   22    Lagos  Orthopedics  Dr. Okeke
# 73        3068  Patient_3068    Female   67   Lagos    Pediatrics  Dr. Smith
#
#    admission_date discharge_date bill_amount insurance diagnosis readmitted
# 69     2024-06-14     2024-06-20      219647        No  Diabetes        Yes
# 70            NaN     2024-07-09     388,537      yes   Diabetes        Yes
# 71     2024-07-17     2024-07-28     275,039       NaN   cancer          No
# 72     2024-07-20     2024-07-26     410,540       NaN  Diabetes         No
# 73     2024-07-10     2024-07-24      311076       NaN    Asthma        Yes

# %%
df.sample(5)
# Out:
#     patient_id          name    gender  age           city   department  \
# 72        3041  Patient_3041    Female   22          Lagos  Orthopedics
# 64        3065  Patient_3065   female    84          Enugu  Orthopedics
# 73        3068  Patient_3068    Female   67         Lagos    Pediatrics
# 40        3041  Patient_3041    Female   22          Lagos  Orthopedics
# 68        3069  Patient_3069      MALE   73  Port Harcourt     Oncology
#
#        doctor admission_date discharge_date bill_amount insurance diagnosis  \
# 72  Dr. Okeke     2024-07-20     2024-07-26     410,540       NaN  Diabetes
# 64  Dr. Bello            NaN     2024-07-21      427935       NaN  Fracture
# 73  Dr. Smith     2024-07-10     2024-07-24      311076       NaN    Asthma
# 40  Dr. Okeke     2024-07-20     2024-07-26     410,540       NaN  Diabetes
# 68  Dr. Smith     2024-06-28     2024-07-01      428563      yes     Cancer
#
#    readmitted
# 72         No
# 64        Yes
# 73        Yes
# ...

# %%
df
# Out:
#     patient_id          name    gender  age     city   department     doctor  \
# 0         3001  Patient_3001      Male   54   Lagos   Orthopedics   Dr. Musa
# 1         3002  Patient_3002   female    81    Abuja   Pediatrics   Dr. Musa
# 2         3003  Patient_3003      Male   47    Enugu    Neurology  Dr. Smith
# 3         3004  Patient_3004      MALE   87   Lagos      Oncology  Dr. Okeke
# 4         3005  Patient_3005   female    79    Lagos    Neurology  Dr. Smith
# ..         ...           ...       ...  ...      ...          ...        ...
# 69        3070  Patient_3070      Male   25    Enugu     Oncology  Dr. Adams
# 70        3009  Patient_3009   female    74   Lagos      Oncology  Dr. Okeke
# 71        3038  Patient_3038   female    59     Kano   Pediatrics  Dr. Adams
# 72        3041  Patient_3041    Female   22    Lagos  Orthopedics  Dr. Okeke
# 73        3068  Patient_3068    Female   67   Lagos    Pediatrics  Dr. Smith
#
# ...

# %% [markdown]
# ## Let's Explore the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      74 non-null     int64
#  1   name            74 non-null     object
#  2   gender          74 non-null     object
#  3   age             74 non-null     int64
#  4   city            74 non-null     object
#  5   department      74 non-null     object
#  6   doctor          74 non-null     object
#  7   admission_date  66 non-null     object
#  8   discharge_date  69 non-null     object
#  9   bill_amount     64 non-null     object
#  10  insurance       50 non-null     object
#  11  diagnosis       74 non-null     object
#  12  readmitted      74 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 7.6+ KB

# %%
# check for duplicates
df.duplicated().any()
# Out:
# np.True_

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70     True
# 71     True
# 72     True
# 73     True
# Length: 74, dtype: bool

# %%
df.shape
# Out:
# (74, 13)

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
#displays the section of the df that has duplicates
df[df.duplicated()]
# Out:
#     patient_id          name    gender  age     city   department     doctor  \
# 70        3009  Patient_3009   female    74   Lagos      Oncology  Dr. Okeke
# 71        3038  Patient_3038   female    59     Kano   Pediatrics  Dr. Adams
# 72        3041  Patient_3041    Female   22    Lagos  Orthopedics  Dr. Okeke
# 73        3068  Patient_3068    Female   67   Lagos    Pediatrics  Dr. Smith
#
#    admission_date discharge_date bill_amount insurance diagnosis readmitted
# 70            NaN     2024-07-09     388,537      yes   Diabetes        Yes
# 71     2024-07-17     2024-07-28     275,039       NaN   cancer          No
# 72     2024-07-20     2024-07-26     410,540       NaN  Diabetes         No
# 73     2024-07-10     2024-07-24      311076       NaN    Asthma        Yes

# %%
df.drop_duplicates(inplace=True)
# inplace = True :  Modifies the DataFrame directly instead of returning a new one

# %%
df
# Out:
#     patient_id          name    gender  age           city    department  \
# 0         3001  Patient_3001      Male   54         Lagos    Orthopedics
# 1         3002  Patient_3002   female    81          Abuja    Pediatrics
# 2         3003  Patient_3003      Male   47          Enugu     Neurology
# 3         3004  Patient_3004      MALE   87         Lagos       Oncology
# 4         3005  Patient_3005   female    79          Lagos     Neurology
# ..         ...           ...       ...  ...            ...           ...
# 65        3066  Patient_3066      Male   33          Lagos     Neurology
# 66        3067  Patient_3067   female    39           Kano   cardiology
# 67        3068  Patient_3068    Female   67         Lagos     Pediatrics
# 68        3069  Patient_3069      MALE   73  Port Harcourt      Oncology
# 69        3070  Patient_3070      Male   25          Enugu      Oncology
#
#        doctor admission_date discharge_date bill_amount insurance diagnosis  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      70 non-null     int64
#  1   name            70 non-null     object
#  2   gender          70 non-null     object
#  3   age             70 non-null     int64
#  4   city            70 non-null     object
#  5   department      70 non-null     object
#  6   doctor          70 non-null     object
#  7   admission_date  63 non-null     object
#  8   discharge_date  65 non-null     object
#  9   bill_amount     60 non-null     object
#  10  insurance       49 non-null     object
#  11  diagnosis       70 non-null     object
#  12  readmitted      70 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 7.7+ KB

# %%
df
# Out:
#     patient_id          name    gender  age           city    department  \
# 0         3001  Patient_3001      Male   54         Lagos    Orthopedics
# 1         3002  Patient_3002   female    81          Abuja    Pediatrics
# 2         3003  Patient_3003      Male   47          Enugu     Neurology
# 3         3004  Patient_3004      MALE   87         Lagos       Oncology
# 4         3005  Patient_3005   female    79          Lagos     Neurology
# ..         ...           ...       ...  ...            ...           ...
# 65        3066  Patient_3066      Male   33          Lagos     Neurology
# 66        3067  Patient_3067   female    39           Kano   cardiology
# 67        3068  Patient_3068    Female   67         Lagos     Pediatrics
# 68        3069  Patient_3069      MALE   73  Port Harcourt      Oncology
# 69        3070  Patient_3070      Male   25          Enugu      Oncology
#
#        doctor admission_date discharge_date bill_amount insurance diagnosis  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      70 non-null     int64
#  1   name            70 non-null     object
#  2   gender          70 non-null     object
#  3   age             70 non-null     int64
#  4   city            70 non-null     object
#  5   department      70 non-null     object
#  6   doctor          70 non-null     object
#  7   admission_date  63 non-null     object
#  8   discharge_date  65 non-null     object
#  9   bill_amount     60 non-null     object
#  10  insurance       49 non-null     object
#  11  diagnosis       70 non-null     object
#  12  readmitted      70 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 7.7+ KB

# %%
df.isnull().sum()
# Out:
# patient_id         0
# name               0
# gender             0
# age                0
# city               0
# department         0
# doctor             0
# admission_date     7
# discharge_date     5
# bill_amount       10
# insurance         21
# diagnosis          0
# readmitted         0
# dtype: int64

# %%
df.shape
# Out:
# (70, 13)

# %%
#calculates the number of rows remaining in the DataFrame after all rows with missing values have been excluded.
#in short form - return the number of rows without missing values
len(df.dropna())
# Out:
# 37

# %%
df.head()
# Out:
#    patient_id          name    gender  age     city   department     doctor  \
# 0        3001  Patient_3001      Male   54   Lagos   Orthopedics   Dr. Musa
# 1        3002  Patient_3002   female    81    Abuja   Pediatrics   Dr. Musa
# 2        3003  Patient_3003      Male   47    Enugu    Neurology  Dr. Smith
# 3        3004  Patient_3004      MALE   87   Lagos      Oncology  Dr. Okeke
# 4        3005  Patient_3005   female    79    Lagos    Neurology  Dr. Smith
#
#   admission_date discharge_date bill_amount insurance diagnosis readmitted
# 0     2024-06-28     2024-07-11      391724       Yes    Cancer        Yes
# 1     2024-06-10     2024-06-18      265621       Yes  Diabetes        Yes
# 2     2024-06-16     2024-06-24     487,807       NaN  Fracture        Yes
# 3     2024-06-05            NaN      391458       NaN  Diabetes        Yes
# 4     2024-06-27     2024-06-30         NaN      yes     Cancer         No

# %%
len(df.dropna(subset=['admission_date', 'discharge_date']))
# Out:
# 58

# %%
df.dropna(subset=['admission_date', 'discharge_date'], inplace=True)

# %%
df.shape
# Out:
# (58, 13)

# %%
#output shows number of rows left in the dataframe - look at the index eg row 3 has been removed
df
# Out:
#     patient_id          name    gender  age           city    department  \
# 0         3001  Patient_3001      Male   54         Lagos    Orthopedics
# 1         3002  Patient_3002   female    81          Abuja    Pediatrics
# 2         3003  Patient_3003      Male   47          Enugu     Neurology
# 4         3005  Patient_3005   female    79          Lagos     Neurology
# 5         3006  Patient_3006      Male   40           Kano      Oncology
# 6         3007  Patient_3007      Male   37          Enugu   cardiology
# 7         3008  Patient_3008      MALE   86         Lagos     Cardiology
# 9         3010  Patient_3010   female    66         Lagos       Oncology
# 10        3011  Patient_3011      Male   77         Lagos     Pediatrics
# 12        3013  Patient_3013    Female   19          Enugu   cardiology
# 13        3014  Patient_3014   female    35           Kano      Oncology
# 14        3015  Patient_3015   female    76          Enugu    Cardiology
# ...

# %%
# resets the index of the df to the default integer index eg (0,1,2..),while discarding old index (above output)
df.reset_index(drop=True)
# Out:
#     patient_id          name    gender  age           city    department  \
# 0         3001  Patient_3001      Male   54         Lagos    Orthopedics
# 1         3002  Patient_3002   female    81          Abuja    Pediatrics
# 2         3003  Patient_3003      Male   47          Enugu     Neurology
# 3         3005  Patient_3005   female    79          Lagos     Neurology
# 4         3006  Patient_3006      Male   40           Kano      Oncology
# 5         3007  Patient_3007      Male   37          Enugu   cardiology
# 6         3008  Patient_3008      MALE   86         Lagos     Cardiology
# 7         3010  Patient_3010   female    66         Lagos       Oncology
# 8         3011  Patient_3011      Male   77         Lagos     Pediatrics
# 9         3013  Patient_3013    Female   19          Enugu   cardiology
# 10        3014  Patient_3014   female    35           Kano      Oncology
# 11        3015  Patient_3015   female    76          Enugu    Cardiology
# ...

# %%
df.shape
# Out:
# (58, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      58 non-null     int64
#  1   name            58 non-null     object
#  2   gender          58 non-null     object
#  3   age             58 non-null     int64
#  4   city            58 non-null     object
#  5   department      58 non-null     object
#  6   doctor          58 non-null     object
#  7   admission_date  58 non-null     object
#  8   discharge_date  58 non-null     object
#  9   bill_amount     51 non-null     object
#  10  insurance       42 non-null     object
#  11  diagnosis       58 non-null     object
#  12  readmitted      58 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
df.columns
# Out:
# Index(['patient_id', 'name', 'gender', 'age', 'city', 'department', 'doctor',
#        'admission_date', 'discharge_date', 'bill_amount', 'insurance',
#        'diagnosis', 'readmitted'],
#       dtype='object')

# %%
# convert data column from object to date data type
df['admission_date'] = pd.to_datetime(df['admission_date'])
df['discharge_date'] = pd.to_datetime(df['discharge_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      58 non-null     int64
#  1   name            58 non-null     object
#  2   gender          58 non-null     object
#  3   age             58 non-null     int64
#  4   city            58 non-null     object
#  5   department      58 non-null     object
#  6   doctor          58 non-null     object
#  7   admission_date  58 non-null     datetime64[ns]
#  8   discharge_date  58 non-null     datetime64[ns]
#  9   bill_amount     51 non-null     object
#  10  insurance       42 non-null     object
#  11  diagnosis       58 non-null     object
#  12  readmitted      58 non-null     object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 6.3+ KB

# %%
df["admission_days"]  = (df['discharge_date'] - df['admission_date']).dt.days

# %%
df.head()
# Out:
#    patient_id          name    gender  age     city   department     doctor  \
# 0        3001  Patient_3001      Male   54   Lagos   Orthopedics   Dr. Musa
# 1        3002  Patient_3002   female    81    Abuja   Pediatrics   Dr. Musa
# 2        3003  Patient_3003      Male   47    Enugu    Neurology  Dr. Smith
# 4        3005  Patient_3005   female    79    Lagos    Neurology  Dr. Smith
# 5        3006  Patient_3006      Male   40     Kano     Oncology  Dr. Smith
#
#   admission_date discharge_date bill_amount insurance diagnosis readmitted  \
# 0     2024-06-28     2024-07-11      391724       Yes    Cancer        Yes
# 1     2024-06-10     2024-06-18      265621       Yes  Diabetes        Yes
# 2     2024-06-16     2024-06-24     487,807       NaN  Fracture        Yes
# 4     2024-06-27     2024-06-30         NaN      yes     Cancer         No
# 5     2024-07-30     2024-08-14       46244       Yes    Cancer        Yes
#
#    admission_days
# 0              13
# 1               8
# ...

# %% [markdown]
# ## Simple analysis

# %%
(df["readmitted"].value_counts(normalize=True) * 100).round(2)
# Out:
# readmitted
# No     53.45
# Yes    46.55
# Name: proportion, dtype: float64

# %% [markdown]
# #### Average stay in the hospital

# %%
df.groupby("readmitted")["admission_days"].mean()
# Out:
# readmitted
# No     8.161290
# Yes    9.777778
# Name: admission_days, dtype: float64

# %% [markdown]
# #### By Diagnosis

# %%
#percentage rate of patients readmitted based on their diagnosis
(df.groupby("diagnosis")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted      No   Yes
# diagnosis
# Hypertension  11.0  89.0
# Diabetes      56.0  44.0
#  cancer       57.0  43.0
# Cancer        58.0  42.0
# Asthma        71.0  29.0
# Fracture      71.0  29.0

# %%
(df.groupby("gender")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted    No   Yes
# gender
# Male        39.0  61.0
#  female     59.0  41.0
# Female      60.0  40.0
# MALE        62.0  38.0

# %%
(df.groupby("age")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round().head()
# Out:
# readmitted  No    Yes
# age
# 18         NaN  100.0
# 37         NaN  100.0
# 81         NaN  100.0
# 57         NaN  100.0
# 54         NaN  100.0

# %%
(df.groupby("department")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted      No   Yes
# department
#  cardiology   17.0  83.0
# Neurology     43.0  57.0
# Oncology      54.0  46.0
# Orthopedics   54.0  46.0
# Pediatrics    67.0  33.0
# Cardiology    71.0  29.0

# %% [markdown]
# ##### >>Based on outputs above more data cleaning is required for more accurate insights

# %%
#### More Da

# %%
# Clean the gender column
df["gender"] = df["gender"].str.strip().str.lower()

# %%
(df.groupby("gender")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted    No   Yes
# gender
# male        48.0  52.0
# female      59.0  41.0

# %%
# Clean the department column
df["department"] = df["department"].str.strip().str.title()

# %%
(df.groupby("department")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted     No   Yes
# department
# Neurology    43.0  57.0
# Cardiology   46.0  54.0
# Oncology     54.0  46.0
# Orthopedics  54.0  46.0
# Pediatrics   67.0  33.0

# %%
# Clean the Diagnosis column
df["diagnosis"] = df["diagnosis"].str.strip().str.title()

# %%
(df.groupby("diagnosis")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted      No   Yes
# diagnosis
# Hypertension  11.0  89.0
# Diabetes      56.0  44.0
# Cancer        58.0  42.0
# Asthma        71.0  29.0
# Fracture      71.0  29.0

# %%
# Create a new column for age group 

# Define a function for age grouping
def age_group(age):
    if age <= 30:
        return "Youth (≤30)"
    elif age <= 45:
        return "Adult (31-45)"
    elif age <= 60:
        return "Middle Age (46-60)"
    else:
        return "Senior (61+)"

# %%
# Apply the function to create a new column
df["age_group"] = df["age"].apply(age_group)

# %%
(df.groupby("age_group")["readmitted"].value_counts(normalize=True).unstack().sort_values("Yes", ascending=False) * 100).round()
# Out:
# readmitted            No   Yes
# age_group
# Adult (31-45)       27.0  73.0
# Youth (≤30)         36.0  64.0
# Middle Age (46-60)  50.0  50.0
# Senior (61+)        76.0  24.0

# %% [markdown]
# ## 📊 Insights from the Analysis
#
# ### 1. Overall Readmission Rate
# - **46.6% of patients were readmitted**.
# - That’s nearly half — a significant challenge for the hospital.
#
# ### 2. Length of Stay
# - Readmitted patients stayed **longer on average (≈9.8 days)** compared to those not readmitted (≈8.2 days).
# - Longer initial stays may indicate more severe conditions or complications.
#
# ### 3. By Department
# - **Neurology (57%)** and **Cardiology (54%)** have the highest readmission rates.
# - **Oncology (46%)** and **Orthopedics (46%)** are more balanced.
# - **Pediatrics (33%)** has the lowest readmission rate.
#
# ### 4. By Diagnosis
# - **Hypertension**: extremely high readmission at **89%** — an urgent red flag.
# - **Diabetes (44%)** and **Cancer (42%)** patients also face moderate readmission risk.
# - **Asthma (29%)** and **Fracture (29%)** have the lowest readmission rates.
#
# ### 5. By Age Group
# - **Adults (31–45)**: highest at **73% readmission**.
# - **Youth (≤30)**: **64% readmitted**.
# - **Middle Age (46–60)**: balanced at **50%**.
# - **Seniors (61+)**: lowest at **24%**, which is unusual and may reflect sample size or mortality bias.
#
# ---
#
# ## 💡 Recommendations
#
# 1. **Focus on chronic conditions**: Provide better follow-up and treatment plans for Hypertension and Diabetes patients.
# 2. **Departmental reviews**: Cardiology and Neurology should strengthen discharge planning and patient education.
# 3. **Age-specific interventions**: Target young and middle-aged adults with lifestyle and adherence programs.
# 4. **Support for long-stay patients**: Provide additional discharge checks and care plans to reduce bounce-back readmissions.
